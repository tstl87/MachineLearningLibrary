# %%
import numpy as np
import pandas as pd
from datetime import datetime
from KNN import KNN, visualizeTrainData, visualizeTestData
from sklearn.model_selection import train_test_split
from util import get_donut, get_xor, get_swirl, get_SBG
import matplotlib.pyplot as plt

# %%
X, y = get_SBG()
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = KNN(5)
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# Training time: 0:00:00
# Train accuracy: 1.0
# Time to compute train accuracy: 0:00:00.002973
# Test accuracy: 1.0
# Time to compute test accuracy: 0:00:00.001995

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_xor()
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = KNN(5)
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# Training time: 0:00:00
# Train accuracy: 0.9625
# Time to compute train accuracy: 0:00:00.004987
# Test accuracy: 0.975
# Time to compute test accuracy: 0:00:00.001994

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_donut()
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = KNN(5)
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# Training time: 0:00:00
# Train accuracy: 1.0
# Time to compute train accuracy: 0:00:00.001994
# Test accuracy: 1.0
# Time to compute test accuracy: 0:00:00.000998

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_swirl()
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = KNN(5)
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# Training time: 0:00:00
# Train accuracy: 0.99375
# Time to compute train accuracy: 0:00:00.004986
# Test accuracy: 1.0
# Time to compute test accuracy: 0:00:00.000997

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
