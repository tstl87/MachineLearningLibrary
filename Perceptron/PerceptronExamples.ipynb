# %%
import numpy as np
import pandas as pd
from datetime import datetime
from Perceptron import Perceptron, visualizeTrainData, visualizeTestData
from sklearn.model_selection import train_test_split
from util import get_donut, get_xor, get_swirl, get_SBG
import matplotlib.pyplot as plt

# %%
X, y = get_SBG()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = Perceptron()
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# final w: [-1.62506401 -1.51122625] final b: -1.0 epochs: 1001 / 1000
# Training time: 0:00:00.108708
# Train accuracy: 1.0
# Time to compute train accuracy: 0:00:00.000997
# Test accuracy: 1.0
# Time to compute test accuracy: 0:00:00.000998

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_xor()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = Perceptron()
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# final w: [0.22081072 0.36453025] final b: 0.0 epochs: 1001 / 1000
# Training time: 0:00:00.130652
# Train accuracy: 0.50625
# Time to compute train accuracy: 0:00:00.000997
# Test accuracy: 0.475
# Time to compute test accuracy: 0:00:00

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_donut()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = Perceptron()
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# final w: [-1.55431633  1.67203703] final b: 2.0 epochs: 1001 / 1000
# Training time: 0:00:00.164560
# Train accuracy: 0.46875
# Time to compute train accuracy: 0:00:00
# Test accuracy: 0.625
# Time to compute test accuracy: 0:00:00

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
X, y = get_swirl()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 95060 )

# %%
model = Perceptron()
t0 = datetime.now()
model.fit(X_train, y_train)
print("Training time:", (datetime.now() - t0))

t0 = datetime.now()
print("Train accuracy:", model.score(X_train, y_train))
print("Time to compute train accuracy:", (datetime.now() - t0))

t0 = datetime.now()
print("Test accuracy:", model.score(X_test, y_test))
print("Time to compute test accuracy:", (datetime.now() - t0))

y_pred = model.predict(X_test)
# Out:
# final w: [ 0.02821152 -0.85555745] final b: 6.0 epochs: 1001 / 1000
# Training time: 0:00:00.153590
# Train accuracy: 0.50625
# Time to compute train accuracy: 0:00:00
# Test accuracy: 0.475
# Time to compute test accuracy: 0:00:00.000997

# %%
visualizeTrainData(X_train, y_train, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
visualizeTestData(X_test, y_test, model)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
